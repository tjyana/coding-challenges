# %%
import pandas as pd

file_path = 'data/ม. 6 ตอบรับความสนใจในการศึกษาต่อ.xlsx'
df = pd.read_excel(file_path, sheet_name='6.1')

# %%
df
# Out:
#    ห้อง ชื่อ -  สกุล                Unnamed: 2  เลขที่  \
# 0   6/1       นางสาว        ปาณิศา แก้วนาเหนือ      17
# 1   6/2          นาย          วีระพงษ์ บุญช่วย       4
# 2   6/2          นาย            เจษฎา ทองดีนอก      24
# 3   6/2          นาย        ธรายุ ดอนจันทร์ทิม      26
# 4   6/3          นาย     ไวกูณฑ์ มงคลศิริวัฒนา       7
# ..  ...          ...                       ...     ...
# 82  6/3       นางสาว          ฑิฆัมพร พรมมาจีน      13
# 83  6/3       นางสาว          ประสิตา วงษ์ป้อง      19
# 84  6/1       นางสาว             ชนิกา แก้วทอง      13
# 85  6/1       นางสาว          สุนิสา เพชรฤทธิ์      21
# 86  6/1       นางสาว  ภัสราภัทร์ ชมพูศรีทรัพย์       6
#
#        ศึกษาต่อ/ไม่ศึกษาต่อ  \
# 0               ไม่ศึกษาต่อ
# 1   เรียนต่อสายอาชีพ/อาชีวะ
# 2   เรียนต่อสายอาชีพ/อาชีวะ
# 3   เรียนต่อสายอาชีพ/อาชีวะ
# 4               ไม่ศึกษาต่อ
# ..                      ...
# 82      เรียนต่อมหาวิทยาลัย
# 83      เรียนต่อมหาวิทยาลัย
# 84      เรียนต่อมหาวิทยาลัย
# ...

# %%
df['คณะที่สนใจลำดับ 1'].value_counts().to_dict()
# Out:
# {'-': 7,
#  'สาขาการตลาด คณะบริหารธุรกิจ มหาวิทยาลัยเกษตรศาสตร์': 2,
#  'สาขาพยาบาลศาสตรบัณฑิต คณะพยาบาลศาสตร์ วิทยาลัยบรมราชชน กรุงเทพ': 1,
#  'สาขาวิชาการจัดการธุรกิจบริการ คณะวิทยาการจัดการ มหาวิทยาลัยราชภัฏสวนสุนันทา': 1,
#  'สาขาวิชา Digital Marketing and Media Creation คณะ บริหารธุรกิจ มหาวิทยาลัยเทคโนโลยีราชมงคลธัญบุรี': 1,
#  'สาขารัฐประศาสนศาสตร์ คณะรัฐศาสตร์ ม.กรุงเทพธนบุรี': 1,
#  'สาขารัฐประศาสนศาสตร์ คณะมนุษยศาสตร์และสังคมศาสตร์ มหาวิทยาลัยราชภัฏบ้านสมเด็จ': 1,
#  'สาขาภาษาอังกฤษ/ศิลปศาสตร์ /มหิดล': 1,
#  'สาขาภาษาญี่ปุ่นเพื่อการสื่อสารธุรกิจ คณะศิลปศาสตร์ มหาวิทยาลัยศรีปทุม': 1,
#  'สาขาไฟฟ้า คณะวิศวกรรมศาสตร์ มหาวิทยาลัยราชมงคลรัตนโกสินทร์': 1,
#  'สาขาพยาบาลศาสตร์ คณะพยาบาลศาสตร์ มหาวิทยาลัยเกษตรศาสตร์': 1,
#  'สาขาการสอนสังคมศึกษา คณะเศรษฐศาสตร์ ธุรกิจ มหาวิทยาลัย เกษตรศาสตร์': 1,
#  'สาขาพยาบาลศาสตร์ คณะพยาบาล มหาวิทยาลัยมหิดล': 1,
#  'สาขาผลิตภาพยนต์และสื่อดิจิทัล วิทยาลัยนวัตกรรมการสื่อสังคม มหาวิทยาลัยศรีนครินทรวิโรฒ': 1,
# ...
