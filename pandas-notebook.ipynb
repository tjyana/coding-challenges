# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Pandas

# %%
# Basic outline of data analysis

# %%
# Make your imports

import pandas as pd
import numpy as np

# %%
# Load your data

df = pd.read_csv('data/activities.csv')
df.head()

# %%
# Examine your data

print(df.head())
print(df.info())
print(df.describe())
print(df.isna().sum())

# %%
# Convert datatypes
# easier to do this before other manipulations? (copy of slice error)
# date columns -> datetime
# categorical columns to category type?

activities['Date'] = pd.to_datetime(activities['Date'])

# %%
# Drop empty columns

activities.dropna(axis=1, how='all', inplace=True)

# %%
# Drop columns with all same value

columns_to_drop = [col for col in activities.columns if activities[col].nunique() == 1]
activities.drop(columns=columns_to_drop, inplace=True)

# %%
# Missing Values
# drop or impute

# drop
activities.dropna(axis=0, how='any', inplace=True)  # Example: drop rows with any missing values

# Alternatively, you can use:
# activities.fillna(method='ffill', inplace=True)  # Forward fill

# %%
# Remove rows that are irrelevant

# Example: Remove activities with zero distance
activities = activities[activities['Distance'] > 0]

# %%
# Remove duplicates

activities.drop_duplicates(inplace=True)

# %%
# Feature engineering

activities['DayOfWeek'] = activities['Date'].dt.day_name()

# %% [markdown]
# # Introduction to Pandas
# - What is Pandas?
# - Installation and Setup
# - Importing Pandas

# %% [markdown]
# # Data Structures
# ## Series
# - Creating a Series
#   - From a list
#   - From a dictionary
#   - From a scalar value
# - Accessing Elements in a Series
#   - Indexing and Slicing
#   - Using `.loc[]` and `.iloc[]`
# - Series Operations
#   - Vectorized operations
#   - Applying functions

# %% [markdown]
# ## DataFrame

# %% [markdown]
# ### Creating a DataFrame
#   - From a dictionary
#   - From a list of dictionaries
#   - From a list of lists
#   - From a CSV/Excel file

# %%
# list of lists
# pd.DataFrame(DATA, columns=['COLUMN1', 'COLUMN2'])

student_data = [[1,15],[2,11],[3,11],[4,20]]

df = pd.DataFrame(data=student_data, columns = ['student_id', 'age'])
df
# Out:
#    student_id  age
# 0           1   15
# 1           2   11
# 2           3   11
# 3           4   20

# %% [markdown]
# ### Examining a DataFrame

# %%
# the masterlist

print(df.head())
print(df.info())
print(df.describe(include='all'))
print(df.isna().sum())

# %% [markdown]
# ##### others

# %%
# .shape
# returns dataframe shape as a tuple
# DF.shape

df = pd.read_csv('data/activities.csv')
df.shape
# Out:
# (20, 38)

# %%
# df.info()

df = pd.read_csv('data/activities.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Activity Type             20 non-null     object
#  1   Date                      20 non-null     object
#  2   Favorite                  20 non-null     bool
#  3   Title                     20 non-null     object
#  4   Distance                  20 non-null     float64
#  5   Calories                  20 non-null     int64
#  6   Time                      20 non-null     object
#  7   Avg HR                    20 non-null     int64
#  8   Max HR                    20 non-null     int64
#  9   Avg Run Cadence           20 non-null     int64
#  10  Max Run Cadence           20 non-null     int64
#  11  Avg Pace                  20 non-null     object
#  12  Best Pace                 20 non-null     object
#  13  Total Ascent              20 non-null     object
# ...

# %%
# .info

df = pd.read_csv('data/activities.csv')
df.info
# Out:
# <bound method DataFrame.info of    Activity Type                 Date  Favorite              Title  Distance  \
# 0        Running  2024-05-09 12:44:32     False  Tama Ward Running      1.63
# 1        Running  2024-05-08 21:03:33     False  Tama Ward Running      0.35
# 2        Running  2024-05-08 19:59:32     False  Tama Ward Running      5.51
# 3        Running  2024-05-07 18:39:11     False  Tama Ward Running      6.00
# 4        Running  2024-05-06 21:55:53     False  Tama Ward Running      1.68
# 5        Running  2024-05-03 22:36:53     False  Tama Ward Running      5.00
# 6        Running  2024-04-30 23:34:16     False  Tama Ward Running      3.08
# 7        Running  2024-04-29 22:18:55     False  Tama Ward Running      5.01
# 8        Running  2024-04-28 22:19:01     False  Tama Ward Running      1.50
# 9        Running  2024-04-27 20:05:36     False  Tama Ward Running      0.32
# 10       Running  2024-04-27 19:23:32     False  Tama Ward Running      1.50
# ...

# %%
# look at datatypes
# df.dtypes

df = pd.read_csv('data/activities.csv')
df.dtypes
# Out:
# Activity Type                object
# Date                         object
# Favorite                       bool
# Title                        object
# Distance                    float64
# Calories                      int64
# Time                         object
# Avg HR                        int64
# Max HR                        int64
# Avg Run Cadence               int64
# Max Run Cadence               int64
# Avg Pace                     object
# Best Pace                    object
# Total Ascent                 object
# Total Descent                object
# Avg Stride Length           float64
# Avg Vertical Ratio          float64
# Avg Vertical Oscillation    float64
# Avg Ground Contact Time       int64
# Training Stress Score®      float64
# Avg Power                     int64
# Max Power                     int64
# Grit                        float64
# Flow                        float64
# Avg. Swolf                    int64
# Avg Stroke Rate               int64
# ...

# %%
# .describe()
# df.describe(include='all') will get you everything
# can also do include='objects'

df = pd.read_csv('data/activities.csv')
df.describe(include='all')
# Out:
#        Activity Type                 Date Favorite              Title  \
# count             20                   20       20                 20
# unique             1                   20        1                  1
# top          Running  2024-05-09 12:44:32    False  Tama Ward Running
# freq              20                    1       20                 20
# mean             NaN                  NaN      NaN                NaN
# std              NaN                  NaN      NaN                NaN
# min              NaN                  NaN      NaN                NaN
# 25%              NaN                  NaN      NaN                NaN
# 50%              NaN                  NaN      NaN                NaN
# 75%              NaN                  NaN      NaN                NaN
# max              NaN                  NaN      NaN                NaN
#
#          Distance    Calories        Time      Avg HR      Max HR  \
# ...

# %% [markdown]
# ### Accessing Data in a DataFrame
#   - Indexing and Slicing
#   - Using `.loc[]` and `.iloc[]`
#   - Selecting columns
#   - Selecting rows

# %%
# indexing
# show rows
# df[start:stop]

df = pd.read_csv('data/activities.csv')
df[0:3]
# Out:
#   Activity Type                 Date  Favorite              Title  Distance  \
# 0       Running  2024-05-09 12:44:32     False  Tama Ward Running      1.63
# 1       Running  2024-05-08 21:03:33     False  Tama Ward Running      0.35
# 2       Running  2024-05-08 19:59:32     False  Tama Ward Running      5.51
#
#    Calories        Time  Avg HR  Max HR  Avg Run Cadence  ...  Min Temp  \
# 0        82  00:09:12.3     128     149              152  ...       0.0
# 1        16  00:01:56.2     128     150              142  ...       0.0
# 2       344    00:32:08     150     171              154  ...       0.0
#
#   Surface Interval Decompression Best Lap Time Number of Laps  Max Temp  \
# 0             0:00            No    00:03:28.8              2       0.0
# 1             0:00            No    00:01:56.2              1       0.0
# 2             0:00            No    00:03:01.3              6       0.0
#
#    Moving Time  Elapsed Time  Min Elevation  Max Elevation
# ...

# %%
# .loc[]
# df.loc[row_label, column_label]
# locate based on label

df = pd.read_csv('data/activities.csv')
df.loc[1, 'Distance']
# Out:
# 0.35

# %%
# .iloc[]
# df.iloc[row_index, column_index]
# locate based on position (index-based)

df = pd.read_csv('data/activities.csv')
df.iloc[0, 1]
# Out:
# '2024-05-09 12:44:32'

# %%
# conditional selection
# df[df['column_name'] > value]

df = pd.read_csv('data/activities.csv')
df[df['Distance'] > 5]
# Out:
#    Activity Type                 Date  Favorite              Title  Distance  \
# 2        Running  2024-05-08 19:59:32     False  Tama Ward Running      5.51
# 3        Running  2024-05-07 18:39:11     False  Tama Ward Running      6.00
# 7        Running  2024-04-29 22:18:55     False  Tama Ward Running      5.01
# 11       Running  2024-04-21 16:25:21     False  Tama Ward Running      5.01
# 15       Running  2024-04-07 19:45:31     False  Tama Ward Running      6.01
# 16       Running  2024-03-31 18:49:40     False  Tama Ward Running     11.00
# 18       Running  2024-03-25 21:19:16     False  Tama Ward Running      5.01
#
#     Calories      Time  Avg HR  Max HR  Avg Run Cadence  ...  Min Temp  \
# 2        344  00:32:08     150     171              154  ...       0.0
# 3        377  00:36:05     146     163              156  ...       0.0
# 7        300  00:30:31     141     159              158  ...       0.0
# ...

# %% [markdown]
# ### DataFrame Operations
#   - Arithmetic operations
#   - Applying functions (e.g., `.apply()`, `.map()`, `.applymap()`)
#   - Aggregation functions (e.g., `.sum()`, `.mean()`, `.max()`, `.min()`)

# %% [markdown]
# # Data Manipulation

# %% [markdown]
# ## Handling Missing Data

# %% [markdown]
# ### Detecting missing data

# %%
# df.isna()

data = {
    'Activity Type': ['Run', 'Bike', 'Swim', None],
    'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04'],
    'Distance': [5.0, None, 2.0, 3.0],
    'Calories': [300, 500, None, 200],
    'Avg Pace': ['5:00', '4:30', None, '5:30']
}
df = pd.DataFrame(data)

print(df.isna())
print(df.isna().sum())
# Out:
#    Activity Type   Date  Distance  Calories  Avg Pace
# 0          False  False     False     False     False
# 1          False  False      True     False     False
# 2          False  False     False      True      True
# 3           True  False     False     False     False
# Activity Type    1
# Date             0
# Distance         1
# Calories         1
# Avg Pace         1
# dtype: int64

# %%
# df.isnull()

print(df.isnull())
print(df.isnull().sum())
# Out:
#    Activity Type   Date  Distance  Calories  Avg Pace
# 0          False  False     False     False     False
# 1          False  False      True     False     False
# 2          False  False     False      True      True
# 3           True  False     False     False     False
# Activity Type    1
# Date             0
# Distance         1
# Calories         1
# Avg Pace         1
# dtype: int64

# %% [markdown]
# ### Filling missing data

# %% [markdown]
# - Using `.fillna()`
#
# Syntax: DataFrame.fillna(value=None, method=None, axis=None, inplace=False, limit=None, downcast=None, **kwargs)
#
# Parameters:
#
# - value : Static, dictionary, array, series or dataframe to fill instead of NaN.
# - method : Method is used if user doesn’t pass any value. Pandas have different methods like bfill, backfill, or ffill which fills the place with value in the Forward index or Previous/Back respectively.
# - axis: axis takes int or string value for rows/columns. Input can be 0 or 1 for Integer and ‘index’ or ‘columns’ for String
# inplace: It is a boolean which makes the changes in data frame itself if True.
# - limit : This is an integer value which specifies maximum number of consecutive forward/backward NaN value fills.
# - downcast : It takes a dict which specifies what dtype to downcast to which one. Like Float64 to int64.
# **kwargs : Any other Keyword arguments

# %%
# making data frame from csv file 
nba = pd.read_csv("nba.csv") 
  
# replacing na values in college with No college 
nba["College"].fillna("No College", inplace = True)

# %% [markdown]
# - Forward and backward fill

# %%
# .fillna()

# %% [markdown]
# ### Dropping missing data
# - Using `.dropna()`
# - Dropping rows and columns

# %%
# drop missing data
# df.dropna(subset=['COLUMN NAMES'])

import pandas as pd

student_data = {
    'student_id': [32, 217, 779, 849],
    'name': ['Piper', None, 'Georgia', 'Willow'],
    'age': [5, 19, 20, 14]
}

students = pd.DataFrame(student_data)
print(students)
print(students.dropna(subset=['name']))
# Out:
#    student_id     name  age
# 0          32    Piper    5
# 1         217     None   19
# 2         779  Georgia   20
# 3         849   Willow   14
#    student_id     name  age
# 0          32    Piper    5
# 2         779  Georgia   20
# 3         849   Willow   14

# %%
# can also do opposite and return all not null values
# df[df['COLUMN NAME'].notnull()]

students[students['name'].notnull()]
# Out:
#    student_id     name  age
# 0          32    Piper    5
# 2         779  Georgia   20
# 3         849   Willow   14

# %% [markdown]
# ### Change dtype

# %%
# change dtype
# df.astype()
# dtypes: int, str, float, etc

df = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': ['a', 'b', 'c', 'd', 'e'],
    'C': [1.1, '1.0', '1.3', 2, 5]})

df['A'] = df['A'].astype(float)
df.dtypes
# Out:
# A    float64
# B     object
# C     object
# dtype: object

# %%
df = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': ['a', 'b', 'c', 'd', 'e'],
    'C': [1.1, '1.0', '1.3', 2, 5]})
 
# using dictionary to convert specific columns
convert_dict = {'A': int,
                'C': float
                }
 
df = df.astype(convert_dict)
print(df.dtypes)
# Out:
# A      int64
# B     object
# C    float64
# dtype: object

# %% [markdown]
# ### Finding columns with only 1 unique value

# %%
# .nunique()
# returns number of unique values in column or df

df = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': ['a', 'b', 'c', 'd', 'e'],
    'C': [1.1, '1.0', '1.3', 2, 5]})

df.nunique()
# Out:
# A    5
# B    5
# C    5
# dtype: int64

# %%
# .unique()
# return unique values in column
# does not work on entire df

df = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': ['a', 'b', 'c', 'd', 'e'],
    'C': [1.1, '1.0', '1.3', 2, 5]})

df['B'].unique()
# Out:
# array(['a', 'b', 'c', 'd', 'e'], dtype=object)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Renaming columns
# - Using `.rename()`

# %%
customer_data = {
    'customer_id': [1, 2, 3, 4, 5, 6],
    'name': ['Ella', 'David', 'Zachary', 'Alice', 'Finn', 'Violet'],
    'email': ['emily@example.com', 'michael@example.com', 'sarah@example.com', 'john@example.com', 'john@example.com', 'alice@example.com']
}

customers = pd.DataFrame(customer_data)

customers.rename(columns = {'name':'SOMETHING CRAZY'}, inplace = True)
customers
# Out:
#    customer_id SOMETHING CRAZY                email
# 0            1            Ella    emily@example.com
# 1            2           David  michael@example.com
# 2            3         Zachary    sarah@example.com
# 3            4           Alice     john@example.com
# 4            5            Finn     john@example.com
# 5            6          Violet    alice@example.com

# %%
# renaming multiple columns using a dict

customer_data = {
    'customer_id': [1, 2, 3, 4, 5, 6],
    'name': ['Ella', 'David', 'Zachary', 'Alice', 'Finn', 'Violet'],
    'email': ['emily@example.com', 'michael@example.com', 'sarah@example.com', 'john@example.com', 'john@example.com', 'alice@example.com']
}
customers = pd.DataFrame(customer_data)

newnames = {'id': 'student_id', 'first': 'first_name', 'last': 'last_name', 'age': 'age_in_years'}

customers.rename(columns = newnames, inplace = True)
customers
# Out:
#    customer_id     name                email
# 0            1     Ella    emily@example.com
# 1            2    David  michael@example.com
# 2            3  Zachary    sarah@example.com
# 3            4    Alice     john@example.com
# 4            5     Finn     john@example.com
# 5            6   Violet    alice@example.com

# %% [markdown]
# ### Replacing values
# - Using `.replace()`

# %% [markdown]
# ### Duplicates
# - Detecting duplicates
# - Removing duplicates

# %%
# remove duplicate rows
# df.drop_duplicates(subset=['COLUMN NAME'])

customer_data = {
    'customer_id': [1, 2, 3, 4, 5, 6],
    'name': ['Ella', 'David', 'Zachary', 'Alice', 'Finn', 'Violet'],
    'email': ['emily@example.com', 'michael@example.com', 'sarah@example.com', 'john@example.com', 'john@example.com', 'alice@example.com']
}

customers = pd.DataFrame(customer_data)
print('before', customers)
print('after', customers.drop_duplicates(subset=['email']))
# Out:
# before    customer_id     name                email
# 0            1     Ella    emily@example.com
# 1            2    David  michael@example.com
# 2            3  Zachary    sarah@example.com
# 3            4    Alice     john@example.com
# 4            5     Finn     john@example.com
# 5            6   Violet    alice@example.com
# after    customer_id     name                email
# 0            1     Ella    emily@example.com
# 1            2    David  michael@example.com
# 2            3  Zachary    sarah@example.com
# 3            4    Alice     john@example.com
# 5            6   Violet    alice@example.com

# %% [markdown]
# ## Creating New Columns

# %% [markdown]
# ### Adding a new column with a constant value

# %%
# df['new_column'] = value

data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}
df = pd.DataFrame(data)

# Adding a new column with a constant value
df['Country'] = 'USA'

df
# Out:
#       Name  Age Country
# 0    Alice   25     USA
# 1      Bob   30     USA
# 2  Charlie   35     USA

# %% [markdown]
# ### Adding a new column based on existing columns

# %%
# df['new_column'] = df['column1'] + df['column2']

data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}
df = pd.DataFrame(data)

df['Age_in_10_years'] = df['Age'] + 10
df
# Out:
#       Name  Age Country  Age_in_10_years
# 0    Alice   25     USA               35
# 1      Bob   30     USA               40
# 2  Charlie   35     USA               45

# %% [markdown]
# ### Using functions to create new columns
# - Using `.apply()`
# - Using `.map()`

# %% [markdown]
# #### .apply()

# %% [markdown]
# s.apply(func, convert_dtype=True, args=())
# - func: .apply takes a function and applies it to all values of pandas series.
# - convert_dtype: Convert dtype as per the function’s operation.
# - args=(): Additional arguments to pass to function instead of series. Return Type: Pandas Series after applied function/operation.

# %%
# .apply()
# df['new_column'] = df['existing_column'].apply(some_function)
# you don't need to loop bc apply does the whole column for you
# returns pandas series
# VERY useful

data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}
df = pd.DataFrame(data)

def age_group(age):
    if age < 30:
        return 'Young'
    else:
        return 'Old'

# Using .apply() to create a new column
df['Age_Group'] = df['Age'].apply(age_group)

df
# Out:
#       Name  Age         City Age_Group
# 0    Alice   25     New York     Young
# 1      Bob   30  Los Angeles       Old
# 2  Charlie   35      Chicago       Old

# %%
# .map()
# mapping_dict = {old_value: new_value, ...}
# df['new_column'] = df['existing_column'].map(mapping_dict)

data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}
df = pd.DataFrame(data)

city_mapping = {'New York': 'NY', 'Los Angeles': 'LA', 'Chicago': 'CHI'}
df['City_Abbreviation'] = df['City'].map(city_mapping)

df
# Out:
#       Name  Age         City City_Abbreviation
# 0    Alice   25     New York                NY
# 1      Bob   30  Los Angeles                LA
# 2  Charlie   35      Chicago               CHI

# %% [markdown]
# ## Data Transformation
# ### Sorting data
# - Using `.sort_values()`
# - Using `.sort_index()`
# ### Ranking data
# - Using `.rank()`
# ### Binning data
# - Using `pd.cut()`
# - Using `pd.qcut()`
#
# ## Data Aggregation and Grouping
# ### Grouping data
# - Using `.groupby()`
# ### Aggregation functions
# - Using `.agg()`
# - Using `.apply()`
# ### Pivot tables
# - Using `.pivot_table()`

# %% [markdown]
# # Merging and Joining
# ## Concatenation

# %% [markdown]
# ### Using `pd.concat()`

# %%
import pandas as pd

# DataFrame 1
student_data = {
    'student_id': [32, 217, 779, 849],
    'name': ['Piper', None, 'Georgia', 'Willow'],
    'age': [5, 19, 20, 14]
}
student_df = pd.DataFrame(student_data)

# DataFrame 2
student_data_2 = {
    'id': [1, 2, 3, 4, 5],
    'first': ['Mason', 'Ava', 'Taylor', 'Georgia', 'Thomas'],
    'last': ['King', 'Wright', 'Hall', 'Thompson', 'Moore'],
    'age': [6, 7, 16, 18, 10]
}
student_df_2 = pd.DataFrame(student_data_2)

# Concatenating the DataFrames
concatenated_df = pd.concat([student_df, student_df_2], ignore_index=True, sort=False)

print(concatenated_df)

# %% [markdown]
# ## Merging
# ### Using `pd.merge()`
# - Inner join
# - Outer join
# - Left join
# - Right join
#
# ## Joining
# ### Using `.join()`
#
# # Input and Output
# ## Reading Data
# ### Reading CSV files
# - Using `pd.read_csv()`
# ### Reading Excel files
# - Using `pd.read_excel()`
# ### Reading JSON files
# - Using `pd.read_json()`
# ### Reading SQL databases
# - Using `pd.read_sql()`
#
# ## Writing Data
# ### Writing to CSV files
# - Using `.to_csv()`
# ### Writing to Excel files
# - Using `.to_excel()`
# ### Writing to JSON files
# - Using `.to_json()`
# ### Writing to SQL databases
# - Using `.to_sql()`
#
# # Time Series Analysis
# ## Date and Time Data
# ### Creating datetime objects
# - Using `pd.to_datetime()`
# ### Date and time properties
# - Accessing properties (e.g., `.dt.year`, `.dt.month`, `.dt.day`)
# ### Date and time arithmetic
# - Using timedelta objects
#
# ## Resampling
# ### Resampling time series data
# - Using `.resample()`
# - Downsampling and upsampling
# ### Rolling windows
# - Using `.rolling()`
# - Applying functions on rolling windows
#
# # Visualization with Pandas
# ## Plotting
# ### Basic plotting
# - Using `.plot()`
# ### Plot customization
# - Adding titles and labels
# - Changing plot styles
# ### Plot types
# - Line plot
# - Bar plot
# - Histogram
# - Box plot
# - Scatter plot
